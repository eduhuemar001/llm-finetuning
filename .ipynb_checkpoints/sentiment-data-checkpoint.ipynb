# %% [markdown]
# ### Install Libraries

# %%
# !pip install datasets
# !pip install youtube-comment-downloader
# !pip install youtube-search-python
# !pip install "httpx<0.24.0"
# Out:
# Requirement already satisfied: datasets in c:\users\marku\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: filelock in c:\users\marku\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\marku\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\marku\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in c:\users\marku\anaconda3\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\users\marku\anaconda3\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in c:\users\marku\anaconda3\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\marku\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\marku\anaconda3\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\marku\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\marku\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\marku\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\marku\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\marku\anaconda3\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\marku\anaconda3\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marku\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marku\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marku\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marku\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\marku\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marku\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marku\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marku\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\marku\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: youtube-comment-downloader in c:\users\marku\anaconda3\lib\site-packages (0.1.76)
# Requirement already satisfied: dateparser in c:\users\marku\anaconda3\lib\site-packages (from youtube-comment-downloader) (1.2.1)
# Requirement already satisfied: requests in c:\users\marku\anaconda3\lib\site-packages (from youtube-comment-downloader) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\marku\anaconda3\lib\site-packages (from dateparser->youtube-comment-downloader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in c:\users\marku\anaconda3\lib\site-packages (from dateparser->youtube-comment-downloader) (2025.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in c:\users\marku\anaconda3\lib\site-packages (from dateparser->youtube-comment-downloader) (2024.9.11)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\marku\anaconda3\lib\site-packages (from dateparser->youtube-comment-downloader) (5.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marku\anaconda3\lib\site-packages (from requests->youtube-comment-downloader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marku\anaconda3\lib\site-packages (from requests->youtube-comment-downloader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marku\anaconda3\lib\site-packages (from requests->youtube-comment-downloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marku\anaconda3\lib\site-packages (from requests->youtube-comment-downloader) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\marku\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->dateparser->youtube-comment-downloader) (1.16.0)
# Requirement already satisfied: tzdata in c:\users\marku\anaconda3\lib\site-packages (from tzlocal>=0.2->dateparser->youtube-comment-downloader) (2023.3)
# Collecting youtube-search-python
#   Downloading youtube_search_python-1.6.6-py3-none-any.whl.metadata (99 kB)
# Requirement already satisfied: httpx>=0.14.2 in c:\users\marku\anaconda3\lib\site-packages (from youtube-search-python) (0.27.0)
# Requirement already satisfied: anyio in c:\users\marku\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (4.2.0)
# Requirement already satisfied: certifi in c:\users\marku\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\marku\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.0.2)
# Requirement already satisfied: idna in c:\users\marku\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (3.7)
# Requirement already satisfied: sniffio in c:\users\marku\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\marku\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.14.2->youtube-search-python) (0.14.0)
# Downloading youtube_search_python-1.6.6-py3-none-any.whl (89 kB)
# Installing collected packages: youtube-search-python
# Successfully installed youtube-search-python-1.6.6
# Collecting httpx<0.24.0
#   Downloading httpx-0.23.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: certifi in c:\users\marku\anaconda3\lib\site-packages (from httpx<0.24.0) (2025.1.31)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx<0.24.0)
#   Downloading httpcore-0.16.3-py3-none-any.whl.metadata (16 kB)
# Collecting rfc3986<2,>=1.3 (from rfc3986[idna2008]<2,>=1.3->httpx<0.24.0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: sniffio in c:\users\marku\anaconda3\lib\site-packages (from httpx<0.24.0) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\marku\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\marku\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0) (4.2.0)
# Requirement already satisfied: idna in c:\users\marku\anaconda3\lib\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx<0.24.0) (3.7)
# Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
# Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Installing collected packages: rfc3986, httpcore, httpx
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.2
#     Uninstalling httpcore-1.0.2:
#       Successfully uninstalled httpcore-1.0.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
# Successfully installed httpcore-0.16.3 httpx-0.23.3 rfc3986-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 4.2.5 requires httpx>=0.25.0, but you have httpx 0.23.3 which is incompatible.

# %%
from datasets import load_dataset, Dataset, concatenate_datasets
import json
import pandas as pd

# === 1. Amazon Reviews (Meinungen, sehr gut für Sentiment) ===
# mlsum_all = load_dataset("mlsum", "de", split="train")
# mlsum_text = mlsum_all.map(lambda x: {"text": x["text"]}, remove_columns=mlsum_all.column_names)

# === 2. OpenSubtitles (Film-Dialoge, implizites Sentiment) ===
# subtitles = load_dataset("opus_books", "de-en", split="train[:20000]")
# subtitles = subtitles.map(lambda x: {"text": x["translation"]["de"]}, remove_columns=subtitles.column_names)


# === 3. SB10k (from Hugging Face) ===
sb10k = load_dataset("Alienmaster/SB10k", split="train")
print(sb10k.column_names)
sb10k = sb10k.map(lambda x: {
    "text": x["Text"],
    "label": x["Sentiment"].lower()  # Convert to 'positive', 'neutral', 'negative'
}, remove_columns=sb10k.column_names)

files.download(sb10k)

# === Kombinieren & Shuffle ===
combined_dataset = concatenate_datasets([sb10k])
combined_dataset = combined_dataset.shuffle(seed=42)

# === Speichern als JSONL ===
with open("german_sentiment_dataset.jsonl", "w", encoding="utf-8") as f:
    for example in combined_dataset:
        json.dump(example, f, ensure_ascii=False)
        f.write("\n")

print(f"✅ Fertig: {len(combined_dataset)} Texte gespeichert.")
# Out:
# ['ID', 'Sentiment', 'Text', 'Normalized', 'POS-Tags', 'Dependency Labels', 'additional Annotations']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-61a108f83f8b> in <cell line: 0>()
#      20 }, remove_columns=sb10k.column_names)
#      21
# ---> 22 files.download(sb10k)
#      23
#      24 # === Kombinieren & Shuffle ===
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     229   """
#     230
# --> 231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
#     233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#
# /usr/lib/python3.11/genericpath.py in exists(path)
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not Dataset

# %% [markdown]
# ### Download Youtube comment data

# %%
import os
import time
from youtubesearchpython import VideosSearch
from youtube_comment_downloader import YoutubeCommentDownloader

# === Config ===
domains = {
    "gaming": ["gaming deutsch", "spiel bewertung", "pc spiele test", "konsole vergleich deutsch"],
    "music": ["deutschrap 2024", "musikvideo reaktion", "musik bewertung"],
    "products": ["produkttest deutsch", "smartphone review deutsch", "technik empfehlung"],
    "politics": ["nachrichten meinung deutsch", "politische debatte deutschland", "bundestag diskussion"],
    "news": ["tagesschau aktuell", "zdf heute meinung", "nachrichten kommentar"],
    "travel": ["hotel erfahrung deutsch", "reisebericht deutschland", "urlaub bewertung"]
}

videos_per_query = 50
max_comments_per_video = 1000
output_file = "youtube_comments_clean.txt"
processed_log = "processed_videos.log"
target_size_MB = 40  # Stop after 5MB

# === Load processed URLs ===
if os.path.exists(processed_log):
    with open(processed_log, "r", encoding="utf-8") as f:
        processed = set(line.strip() for line in f)
else:
    processed = set()

downloader = YoutubeCommentDownloader()

def file_size_mb(path):
    return os.path.getsize(path) / (1024 * 1024) if os.path.exists(path) else 0

with open(output_file, "a", encoding="utf-8") as out_file, open(processed_log, "a", encoding="utf-8") as log_file:
    for domain, queries in domains.items():
        for query in queries:
            print(f"\nSearching: {query}")
            try:
                videos_search = VideosSearch(query, limit=videos_per_query)
                results = videos_search.result()["result"]
            except Exception as e:
                print(f"Search failed: {e}")
                continue

            for video in results:
                url = video["link"]
                if url in processed:
                    print(f"Skipping: already processed {url}")
                    continue

                print(f"Processing: {video['title']}\n    URL: {url}")
                try:
                    count = 0
                    for comment in downloader.get_comments_from_url(url, sort_by=0):
                        text = comment.get("text", "").strip()
                        if text:
                            clean_text = text.replace("\r", " ").replace("\n", " ").strip()
                            out_file.write(clean_text + "\n")
                            count += 1
                            
                            if count >= max_comments_per_video:
                                break
                            if file_size_mb(output_file) >= target_size_MB:
                                print(f"\nReached {target_size_MB}MB — stopping.")
                                raise StopIteration

                    print(f"   Saved {count} comments.")
                    log_file.write(url + "\n")
                    log_file.flush()

                except StopIteration:
                    raise
                except Exception as e:
                    print(f"Comment scraping error: {e}")
                    continue

                time.sleep(1)
# Out:
# Searching: gaming deutsch
# Skipping: already processed https://www.youtube.com/watch?v=5DnJbnMhXNM
# Skipping: already processed https://www.youtube.com/watch?v=Kzlb526z-Jg
# Processing: Endlich habe ich es fertig geterraformed... #MorizzGMC #minecraft
#     URL: https://www.youtube.com/watch?v=YeXu47loaQQ
#    ✔ Saved 16 comments.
# Processing: Dieses Horrorspiel gibt mir einen Herzinfarkt...
#     URL: https://www.youtube.com/watch?v=C5dsZZGVzsM
#    ✔ Saved 626 comments.
# Processing: Ich baue den besten Gaming PC der Welt
#     URL: https://www.youtube.com/watch?v=yOvm9EoHRBE
#    ✔ Saved 1000 comments.
# Processing: Das LUSTIGSTE Game seit Lethal Company!
#     URL: https://www.youtube.com/watch?v=fIo4o7YyFqI
#    ✔ Saved 306 comments.
# Processing: High-Tech BLITZER! 📸 - GTA 5 LSPD:FR #193 - Daniel Gaming - Deutsch
#     URL: https://www.youtube.com/watch?v=V2q-mEuzLo8
#    ✔ Saved 275 comments.
# Processing: ASMR - ICH SPIELE CLASH ROYALE [GAMING] (GERMAN) | ASMR Tony
#     URL: https://www.youtube.com/watch?v=Y2tfCDMlc74
#    ✔ Saved 17 comments.
# Processing: Jeden Tag nur 1 Sache in Minecraft machen #daily #minecraft #gaming #deutsch
#     URL: https://www.youtube.com/watch?v=2bRl9UNJWds
#    ✔ Saved 1 comments.
# Processing: STOP! Bevor ihr 2025 einen GAMING PC kauft... schaut am besten DIESES Video!
#     URL: https://www.youtube.com/watch?v=EuZA5nl3hos
#    ✔ Saved 826 comments.
# Processing: Squid Game: Staffel 2 | Offizieller Trailer | Netflix
#     URL: https://www.youtube.com/watch?v=mJXg1k5OhSY
#    ✔ Saved 186 comments.
# Processing: Originale Großstadt! 🏙 - Euro Truck Simulator 2 #13 - Daniel Gaming - Deutsch
#     URL: https://www.youtube.com/watch?v=wRIilTwtcY4
#    ✔ Saved 442 comments.
# Processing: WELCHER YOUTUBER überlebt SQUID GAME? 😱
#     URL: https://www.youtube.com/watch?v=7bKNdZlLrlc
#    ✔ Saved 139 comments.
# Processing: Wir spielen den Breaking Bad Simulator...
#     URL: https://www.youtube.com/watch?v=6lT-eXOKnH4
#    ✔ Saved 1000 comments.
# Processing: WIR BRAUCHEN VERSTÄRKUNG ❗❗❗ | Hell Let Loose
#     URL: https://www.youtube.com/watch?v=jqmm1xG2HcM
#    ✔ Saved 1000 comments.
# Processing: Die legendäre GESCHICHTE von RUSSELL😱 [Fortnite]
#     URL: https://www.youtube.com/watch?v=SGBDFy8xWiM
#    ✔ Saved 54 comments.
# Processing: Die Aufgabe ist das Spiel zu schließen???
#     URL: https://www.youtube.com/watch?v=Veo6nET70dw
#    ✔ Saved 815 comments.
# Processing: SQUID GAME Staffel 2 Finaler Trailer German Deutsch (2024) Netflix
#     URL: https://www.youtube.com/watch?v=QJyadmgBHp8
#    ✔ Saved 186 comments.
# Processing: Das BRUTALSTE MÄRCHEN der WELT - Bramble The Mountain King Full Game Deutsch
#     URL: https://www.youtube.com/watch?v=AZOnWCn1m4Q
#    ✔ Saved 429 comments.
# Processing: SQUID GAME Staffel 2 Trailer 2 German Deutsch (2024) Netflix
#     URL: https://www.youtube.com/watch?v=mt02_AjhaRM
#    ✔ Saved 424 comments.
#
# Searching: spiel bewertung
# Skipping: already processed https://www.youtube.com/watch?v=9rYeRy6HFIk
# Skipping: already processed https://www.youtube.com/watch?v=K7uVrIbq9AY
# Processing: Spiel doch mal DORFROMANTIK! - Brettspiel Rezension Meinung Test #439
#     URL: https://www.youtube.com/watch?v=NWs5lJISAVs
#    ✔ Saved 26 comments.
# Processing: Flügelschlag / Wingspan - Rezension  (Kennerspiel des Jahres 2019)
#     URL: https://www.youtube.com/watch?v=WMnqFvepno4
#    ✔ Saved 91 comments.
# Processing: Spiel doch mal SKY TEAM! - Brettspiel Rezension Meinung Test #479
#     URL: https://www.youtube.com/watch?v=XYhDahKM9h8
#    ✔ Saved 17 comments.
# Processing: Spiel doch mal PALEO! - Brettspiel Rezension Meinung Test #351
#     URL: https://www.youtube.com/watch?v=BWFSCle3eM0
#    ✔ Saved 23 comments.
# Processing: Hier ist endlich wieder ein richtig gutes Survival-Spiel!  - Raft im Test / Review
#     URL: https://www.youtube.com/watch?v=SDCeercvLVs
#    ✔ Saved 195 comments.
# Processing: Spiel doch mal CASCADIA! - Brettspiel Rezension Meinung Test #409
#     URL: https://www.youtube.com/watch?v=snYYfTunZ6Y
#    ✔ Saved 27 comments.
# Processing: Thehunter:COTW - Map Roulette  #thehuntercotw
#     URL: https://www.youtube.com/watch?v=U_KWwfLpu8k
#    ✔ Saved 0 comments.
# Processing: Ich habe GEBRAUCHTE Pokemon Spiele gekauft und DAS darauf gefunden! 👀
#     URL: https://www.youtube.com/watch?v=o9QlWMBbV3Y
#    ✔ Saved 169 comments.
# Processing: video spiel bewertung
#     URL: https://www.youtube.com/watch?v=UiAXwC2ouFQ
#    ✔ Saved 2 comments.
# Processing: Eine Runde „Wer bin ich?“ mit Laserluca und Selfiesandra! #Werbinich #youtuber #raten #Spiel
#     URL: https://www.youtube.com/watch?v=RZrv2q_ign0
#    ✔ Saved 2 comments.
# Processing: Ist das das beste Spiel der Welt? Lustige Bewertungen!
#     URL: https://www.youtube.com/watch?v=FHR9C0GoPvo
#    ✔ Saved 5 comments.
# Processing: Farming Simulator 25 Steam Bewertung....
#     URL: https://www.youtube.com/watch?v=rPkiuHkDMOU
#    ✔ Saved 2 comments.
# Processing: Asmodee Kartoffelkönig Spielbewertung | Mirjams spaßige Familien-Spielabend-Erfahrung
#     URL: https://www.youtube.com/watch?v=bt8oCfio4y0
#    ✔ Saved 0 comments.
# Processing: Spiel bewertung Part 5 oder 6
#     URL: https://www.youtube.com/watch?v=JZJ8MJq0m8A
#    ✔ Saved 0 comments.
# Skipping: already processed https://www.youtube.com/watch?v=mYPmafswVLA
# Processing: Das Spiel Meme Club - meine Bewertung
#     URL: https://www.youtube.com/watch?v=ww5tDYwxqPY
#    ✔ Saved 0 comments.
# Processing: Call of Duty Modern Warfare REVIEW Testbericht #waffenspiel Bewertung 🔥#stich #shorts #unterhaltung
#     URL: https://www.youtube.com/watch?v=euICci1i96g
#    ✔ Saved 4 comments.
# Processing: 💎 WWE 2K25 - TEST | Das beste WWE-Spiel seit Jahren? Kann es mit dem aktuellen Hype mithalten?
#     URL: https://www.youtube.com/watch?v=TXq4kiq8MV8
#    ✔ Saved 54 comments.
# Processing: Enttäuschendes Spiel trotz toller Open World - Assassin's Creed Valhalla im Test / Review
#     URL: https://www.youtube.com/watch?v=f2VxzM9jXnU
#    ✔ Saved 1000 comments.
# Processing: Star Wars Jedi: Fallen Order im Test / Review
#     URL: https://www.youtube.com/watch?v=Qdvjjw8NpS8
#    ✔ Saved 1000 comments.
# Processing: Asmodee Kartoffelkönig Spielbewertung | Mirjams spaßige Familien-Spielabend-Erfahrung
#     URL: https://www.youtube.com/watch?v=bt8oCfio4y0
#    ✔ Saved 0 comments.
# Processing: Spiel bewertung Part 5 oder 6
#     URL: https://www.youtube.com/watch?v=JZJ8MJq0m8A
#    ✔ Saved 0 comments.
# Skipping: already processed https://www.youtube.com/watch?v=mYPmafswVLA
# Processing: Das Spiel Meme Club - meine Bewertung
#     URL: https://www.youtube.com/watch?v=ww5tDYwxqPY
#    ✔ Saved 0 comments.
# Processing: Call of Duty Modern Warfare REVIEW Testbericht #waffenspiel Bewertung 🔥#stich #shorts #unterhaltung
#     URL: https://www.youtube.com/watch?v=euICci1i96g
#    ✔ Saved 4 comments.
# Processing: Asmodee Kartoffelkönig Spielbewertung | Sofias spaßiger und schneller Familienspieltest
#     URL: https://www.youtube.com/watch?v=r9UytVGtHVg
#    ✔ Saved 0 comments.
# Processing: Hunt Showdown 1896 Steam Bewertung....
#     URL: https://www.youtube.com/watch?v=V-Rp2YWaq1k
#    ✔ Saved 0 comments.
# Processing: Das Lord of the Rings Gollum Spiel: Mängel und Kritik im Test
#     URL: https://www.youtube.com/watch?v=W6ee_HnaXXg
#    ✔ Saved 1 comments.
# Processing: Steam Bewertungen zu DayZ #steam #horror #review #gaming #comedy
#     URL: https://www.youtube.com/watch?v=C5cw9QEm0Zc
#    ✔ Saved 45 comments.
# Processing: Brookhaven #spielbewertung#roblox#robloxshorts#robloxspiele#like#subscribe#brookhaven#neu
#     URL: https://www.youtube.com/watch?v=OYMkHXx9tyY
#    ✔ Saved 3 comments.
# Processing: Das beste Singleplayer-Survivalspiel? - Subnautica im Test
#     URL: https://www.youtube.com/watch?v=FwY-tG6BQPM
#    ✔ Saved 508 comments.
# Processing: Cascadia – Spiel des Jahres 2022 – Brettspiel – Review und Regelerklärung
#     URL: https://www.youtube.com/watch?v=qwxxyXZrDRs
#    ✔ Saved 68 comments.
# Processing: Planet Coaster 2 geht baden! - Test / Review zum neuen Freizeitpark-Spiel
#     URL: https://www.youtube.com/watch?v=rITSkmzFvfc
#    ✔ Saved 171 comments.
# Processing: The Witcher - Die Alte Welt - Abenteuer Brettspiel - Review
#     URL: https://www.youtube.com/watch?v=llgM3cZ5gj0
#    ✔ Saved 101 comments.
# Processing: Akropolis– Brettspiel – Review und Regelerklärung
#     URL: https://www.youtube.com/watch?v=t_9iUpUAsv4
#    ✔ Saved 17 comments.
# Processing: Elex Test / Review -  Das beste Piranha-Bytes-Spiel seit Gothic 2 (Gameplay)
#     URL: https://www.youtube.com/watch?v=kHfLWvK2Sow
#    ✔ Saved 1000 comments.
# Processing: Marvel's Guardians of the Galaxy ist zum Heulen gut! - Test / Review
#     URL: https://www.youtube.com/watch?v=Hr6uzqP65_Q
#    ✔ Saved 579 comments.
# Processing: Scout – Nominiert zum Spiel des Jahres 2022 – Brettspiel – Review und Regelerklärung
#     URL: https://www.youtube.com/watch?v=t17TAHTT4ho
#    ✔ Saved 30 comments.
#
# Searching: pc spiele test
# Skipping: already processed https://www.youtube.com/watch?v=vV1NyajB0KU
# Skipping: already processed https://www.youtube.com/watch?v=8I6uqfkNaOY
# Skipping: already processed https://www.youtube.com/watch?v=N76198i_VBY
# Skipping: already processed https://www.youtube.com/watch?v=Hap3EcmKJZk
# Processing: Ghost of Tsushima auf dem PC ist eine fast perfekte Punktlandung!
#     URL: https://www.youtube.com/watch?v=hJU8RRqriok
#    ✔ Saved 438 comments.
# Processing: Assassin's Creed Shadows bringt die Open World-Reihe endlich wieder auf Kurs! - Review / Test
#     URL: https://www.youtube.com/watch?v=RcJQOsV_QK0
#    ✔ Saved 1000 comments.
# Processing: Die 15 wichtigsten Open-World-Games für 2025
#     URL: https://www.youtube.com/watch?v=IWQXd8lTUcI
#    ✔ Saved 511 comments.
# Skipping: already processed https://www.youtube.com/watch?v=xJM_XewhOWk
# Processing: Spiele-Releases im April 2025 | Für PC und Konsolen
#     URL: https://www.youtube.com/watch?v=PeasZf8LpJs
#    ✔ Saved 109 comments.
# Processing: Hier ist endlich wieder ein richtig gutes Survival-Spiel!  - Raft im Test / Review
#     URL: https://www.youtube.com/watch?v=SDCeercvLVs
#    ✔ Saved 195 comments.
# Processing: Spiele-Releases im Mai 2025 | Für PC und Konsolen
#     URL: https://www.youtube.com/watch?v=NaTe83v8YYg
#    ✔ Saved 91 comments.
# Processing: Doom - Test-Video: So modern ist der Oldschool-Shooter
#     URL: https://www.youtube.com/watch?v=HMIPng6K1gU
#    ✔ Saved 378 comments.
# Processing: Marvel's Guardians of the Galaxy ist zum Heulen gut! - Test / Review
#     URL: https://www.youtube.com/watch?v=Hr6uzqP65_Q
#    ✔ Saved 579 comments.
# Processing: Sniper Elite Resistance | REVIEW | Jetzt geht's den Nazis wieder an die Nüsse!
#     URL: https://www.youtube.com/watch?v=QlG5urSUgv0
#    ✔ Saved 67 comments.
# Processing: RTX 4060 vs RTX 3070 game test💀🔥😱#gaming #pc #fps #productreview
#     URL: https://www.youtube.com/watch?v=14jx1w5r0eY
#    ✔ Saved 145 comments.
# Processing: Ich teste den besten Gaming PC der Welt
#     URL: https://www.youtube.com/watch?v=zeOyA3-WrcM
#    ✔ Saved 434 comments.
# Processing: Einsteigen, durchladen, FEUERN! - Die Panzer-Simulation Gunner, HEAT, PC! im Test
#     URL: https://www.youtube.com/watch?v=r0FUxlBGg44
#    ✔ Saved 253 comments.
# Processing: Eine komplizierte Liebe - Steam Deck im Test / Review
#     URL: https://www.youtube.com/watch?v=_eCLmmx_n5o
#    ✔ Saved 1000 comments.
# Processing: Gaming PC für unter 150€ - Was kann die XBOX Series S?
#     URL: https://www.youtube.com/watch?v=woSiYWRjdyU
#    ✔ Saved 196 comments.
# Processing: Top 100 Best PC Games from the Last 12 Years | Action, Racing, FPS & More
#     URL: https://www.youtube.com/watch?v=7KFEtvPBbzc
#    ✔ Saved 843 comments.
#
# Searching: konsole vergleich deutsch
# Skipping: already processed https://www.youtube.com/watch?v=U6krwuyr9ZQ
# Skipping: already processed https://www.youtube.com/watch?v=ijRuyB_N0T4
# Skipping: already processed https://www.youtube.com/watch?v=jCgO44PW7dI
# Skipping: already processed https://www.youtube.com/watch?v=2qmHU79cxuo
# Processing: Playstation 5, Xbox Series X oder Nintendo Switch? Wer gewinnt das Konsolenbattle? | Galileo
#     URL: https://www.youtube.com/watch?v=BQ5eRgcbPak
#    ✔ Saved 1000 comments.
# Processing: Nintendo Switch OLED & Nintendo Switch | Vergleich & Unterschiede der Konsolen [Deutsch|HD]
#     URL: https://www.youtube.com/watch?v=T8UQUe2r8oI
#    ✔ Saved 3 comments.
# Processing: PS5 oder Switch? Vergleich der Topseller: 2023
#     URL: https://www.youtube.com/watch?v=-hC0S8ssxbo
#    ✔ Saved 216 comments.
# Processing: Vergleich Spielekonsolen Sony vs Microsoft vs Nintendo
#     URL: https://www.youtube.com/watch?v=tirf--yIN7s
#    ✔ Saved 2 comments.
# Processing: Gaming PC oder Konsole | Der  Vergleich [Deutsch/German]
#     URL: https://www.youtube.com/watch?v=H5sN-R04t0s
#    ✔ Saved 0 comments.
# Processing: Die PLAYSTATION 5 PRO & was du VOR DEM KAUF wissen solltest
#     URL: https://www.youtube.com/watch?v=5w6LlkFwPOI
#    ✔ Saved 677 comments.
# Processing: ROG Ally vs. Legion Go vs. Steam Deck OLED vs. Steam Deck - Die besten Gaming Handhelds 2024 im Test
#     URL: https://www.youtube.com/watch?v=MmJQmFqb_6Y
#    ✔ Saved 136 comments.
# Processing: PlayStation 5 Pro im Test | PRObiers nochmal, Sony | PS5 Pro vs PS5 vs PC Kaufberatung
#     URL: https://www.youtube.com/watch?v=t_WwNcRnM0I
#    ✔ Saved 93 comments.
# Processing: PS5 Pro im Technik-Check: Für wen lohnt sie sich?
#     URL: https://www.youtube.com/watch?v=Su6F8yN4C3Q
#    ✔ Saved 882 comments.
# Processing: PS5 Pro - Warum ein PC nicht mithalten kann!
#     URL: https://www.youtube.com/watch?v=3r1FAcf-HKg
#    ✔ Saved 777 comments.
# Processing: Warum alle Handheld PCs kacke sind. (Außer einer...)
#     URL: https://www.youtube.com/watch?v=nNXaGaixF7c
#    ✔ Saved 1000 comments.
# Processing: Die besten Gaming-Handhelds 2024/2025 im Test
#     URL: https://www.youtube.com/watch?v=BwEJuvkeVvo
#    ✔ Saved 202 comments.
# Processing: Fazit nach 3 Jahren:  PlayStation 5 vs. Xbox Series X (Test)
#     URL: https://www.youtube.com/watch?v=1YgtzCciqi4
#    ✔ Saved 224 comments.
# Processing: Vorsicht: Diese Nintendo Switch solltest du dir 2024 kaufen!
#     URL: https://www.youtube.com/watch?v=seB5qQjbHwI
#    ✔ Saved 142 comments.
# Processing: Xbox Series X vs Series S: Spar dir das Geld!
#     URL: https://www.youtube.com/watch?v=MLC0661y-o8
#    ✔ Saved 1000 comments.
# Processing: Deshalb solltest du KEINE PS5 Slim kaufen!
#     URL: https://www.youtube.com/watch?v=z_iQlXSbPuY
#    ✔ Saved 438 comments.
#
# Searching: deutschrap 2024
# Skipping: already processed https://www.youtube.com/watch?v=s1phjLbyI88
# Skipping: already processed https://www.youtube.com/watch?v=Euez4oc1V4g
# Skipping: already processed https://www.youtube.com/watch?v=ChIJTsTviiQ
# Skipping: already processed https://www.youtube.com/watch?v=3OyNt7ILzp8
# Processing: 🇩🇪  DeutschRap Mix #23 🥶 Best of German Rap 2020  - Dj StarSunglasses @DjStarSunglasses
#     URL: https://www.youtube.com/watch?v=qtKigItsSUk
#    ✔ Saved 154 comments.
# Processing: LACAZETTE - H&K
#     URL: https://www.youtube.com/watch?v=VN6KKXUMaik
#    ✔ Saved 1000 comments.
# Processing: Olexesh x Mel - SCHUTZENGEL (prod. von m3) [official video]
#     URL: https://www.youtube.com/watch?v=R4CB5caKqVU
#    ✔ Saved 403 comments.
# Processing: AZET - TAGEBUCH (Official Video)
#     URL: https://www.youtube.com/watch?v=0bdSl8NjMg4
#    ✔ Saved 680 comments.
# Processing: Alors
#     URL: https://www.youtube.com/watch?v=3ZPitAU1bgg
#    ✔ Saved 831 comments.
# Processing: Amo x Nimo - RAPSTAR (prod. von SVRN BEATS) [Official Video]
#     URL: https://www.youtube.com/watch?v=bpt4YD7Ca0g
#    ✔ Saved 1000 comments.
# Processing: 187 Allstars 2024 (Jambeatz)
#     URL: https://www.youtube.com/watch?v=pGob7e7Oor0
#    ✔ Saved 1000 comments.
# Processing: kc rebell - manchmal (prod. by mb & akid)
#     URL: https://www.youtube.com/watch?v=Vl6C-GZzZBk
#    ✔ Saved 1000 comments.
# Processing: SAMRA - WENN DU MICH SIEHST (prod. by Lukas Piano & Maik The Maker) [Official Video]
#     URL: https://www.youtube.com/watch?v=iwKkpKGl00w
#    ✔ Saved 1000 comments.
# Processing: LACAZETTE - ICH [Outro 2024]
#     URL: https://www.youtube.com/watch?v=q-MZkMazikc
#    ✔ Saved 1000 comments.
# Processing: SAMRA - NASSER ASPHALT (prod. by Lukas Piano, Chris Jarbee & terence.killt) [Official Video]
#     URL: https://www.youtube.com/watch?v=6yfp0LWvVZI
#    ✔ Saved 763 comments.
# Processing: Veysel – BERETTA [Official Video]
#     URL: https://www.youtube.com/watch?v=UqFvwuXBXm0
#    ✔ Saved 495 comments.
# Processing: BOBBY VANDAMME - GHETTO [official Video]
#     URL: https://www.youtube.com/watch?v=bErd9q0n3yA
#    ✔ Saved 1000 comments.
# Processing: NIMO - Mittelmeer (prod. by Lord JKO & DJ Samir)
#     URL: https://www.youtube.com/watch?v=vW8GRGLiKOk
#    ✔ Saved 552 comments.
# Processing: PA SPORTS x YAKARY - REALITY (Official Video)
#     URL: https://www.youtube.com/watch?v=ohHS9bbI1Vo
#    ✔ Saved 899 comments.
# Processing: [FREE] AMO TYPE BEAT - ''Dunya'' (prod. by kaythe808plug)
#     URL: https://www.youtube.com/watch?v=2mMDsOoFvnA
#    ✔ Saved 1 comments.
# Processing: 🇩🇪  DEUTSCHRAP MIX 2025 ⚡ BEST OF 2024 HITS 🔥 - Dj StarSunglasses
#     URL: https://www.youtube.com/watch?v=zxRdqMNns3I
#    ✔ Saved 8 comments.
# Processing: MERO - Qualité [Official Video]
#     URL: https://www.youtube.com/watch?v=1RejAK3NeeI
#    ✔ Saved 1000 comments.
# Processing: DARDAN & AZET - PA MU (OFFICIAL VIDEO)
#     URL: https://www.youtube.com/watch?v=MxDxJMw1fWA
#    ✔ Saved 1000 comments.
# Processing: Sosa La M x Luciano - Butcher (prod. by nilly)
#     URL: https://www.youtube.com/watch?v=K0026Vz_Ds0
#    ✔ Saved 997 comments.
# Processing: Veysel – GUT (prod. Johnny Good & Julez) [Official Video]
#     URL: https://www.youtube.com/watch?v=Y213QbyetGU
#    ✔ Saved 139 comments.
# Processing: 🇩🇪  DEUTSCHRAP MIX 2022 ⚡ BEST OF 2021 HITS 🔥 - Dj StarSunglasses  @DjStarSunglasses
#     URL: https://www.youtube.com/watch?v=L43LoTtkyXI
#    ✔ Saved 249 comments.
# Processing: CAPITAL BRA - PARANOIA
#     URL: https://www.youtube.com/watch?v=YIHQzwMxUFI
#    ✔ Saved 1000 comments.
#
# Searching: musikvideo reaktion
# Skipping: already processed https://www.youtube.com/watch?v=sIn-ep8j4F0
# Skipping: already processed https://www.youtube.com/watch?v=oM3q9trC9o8
# Skipping: already processed https://www.youtube.com/watch?v=HmkMyQjwh4g
# Processing: Freshtorge - Olaf Scholz Song (Offizielles Musikvideo) | REAKTION
#     URL: https://www.youtube.com/watch?v=_kOtTxtCOek
#    ✔ Saved 59 comments.
# Processing: Helga & Marianne - Kann ich nicht (Offizielles Musikvideo) | REAKTION
#     URL: https://www.youtube.com/watch?v=wpH9JggA3E0
#    ✔ Saved 98 comments.
# Skipping: already processed https://www.youtube.com/watch?v=mIF26D_Gj34
# Processing: REAKTION auf Sandra - Mathe ist ein Arsch (Official Music Video) | freshtorge
#     URL: https://www.youtube.com/watch?v=R6rf6FjU1dM
#    ✔ Saved 43 comments.
# Processing: JALAL - DU BIST MEIN CRUSH REAKTION 😖
#     URL: https://www.youtube.com/watch?v=ADBhoBUAGrQ
#    ✔ Saved 365 comments.
# Processing: Geboren um zu leben - Kontra K feat. NESS  [Reaktion Video]
#     URL: https://www.youtube.com/watch?v=jn9FGPzw4C8
#    ✔ Saved 0 comments.
# Processing: Eminem reagiert auf the Voice Kids Germany! #shorts
#     URL: https://www.youtube.com/watch?v=l2denbgV4sE
#    ✔ Saved 438 comments.
# Processing: Reaktion 😏
#     URL: https://www.youtube.com/watch?v=Yo_2i49eoRY
#    ✔ Saved 45 comments.
# Skipping: already processed https://www.youtube.com/watch?v=g90l1iuH5lY
# Processing: ok, KRASS...! AYLIVA - Wie? (Official Video)
#     URL: https://www.youtube.com/watch?v=tiY1Jk0fkkc
#    ✔ Saved 99 comments.
# Processing: GÄNSEHAUT 😱 SAMI reagiert auf "MUCCO - ABSEITS"
#     URL: https://www.youtube.com/watch?v=GV_3ODHXiTg
#    ✔ Saved 19 comments.
# Processing: ICH BIN SPRACHLOS! 😳 (ich vor 10 Jahren) | Reaktion auf alte Videos
#     URL: https://www.youtube.com/watch?v=UtvA2jL8IAU
#    ✔ Saved 106 comments.
# Processing: Diese Reaktion Kam ÜBERRASCHEND! ✈️😂
#     URL: https://www.youtube.com/watch?v=FjLSjPx4T40
#    ✔ Saved 3 comments.
# Processing: REZO und JU haben ApoRed gedisst - REAKTION auf ALTE Videos
#     URL: https://www.youtube.com/watch?v=vxfSa1zIJjI
#    ✔ Saved 798 comments.
# Processing: Luca Meme Song | REAKTION
#     URL: https://www.youtube.com/watch?v=fwSb18Kauvk
#    ✔ Saved 278 comments.
# Processing: MontanaBlack REAGIERT auf DEUTSCHRAP MEMES!😂 MontanaBlack Reaktion
#     URL: https://www.youtube.com/watch?v=2Y62EEb0JlM
#    ✔ Saved 1000 comments.
# Processing: 😱😨JULES mit FETTEM VIDEO über DEUTSCHLAND! - REAKTION | Trymacs Stream Highlights
#     URL: https://www.youtube.com/watch?v=hu5Wcgj966o
#    ✔ Saved 1000 comments.
#
# Searching: musik bewertung
# Skipping: already processed https://www.youtube.com/watch?v=rqq9X84bA3I
# Processing: 30 Minute Focus - Dreamlight ⚡ Brain.fm ⚡ Music for Maximum Focus and Concentration
#     URL: https://www.youtube.com/watch?v=UpPmnnJcy6A
#    ✔ Saved 710 comments.
# Skipping: already processed https://www.youtube.com/watch?v=h-EsT_X3Vfo
# Skipping: already processed https://www.youtube.com/watch?v=RVKIJy3nf0Q
# Skipping: already processed https://www.youtube.com/watch?v=b6UEbp27EQ0
# Processing: YouTuber BEWERTEN meinen SONG (Standart Skill, Avive, ..)
#     URL: https://www.youtube.com/watch?v=CLhbhCxV2w8
#    ✔ Saved 799 comments.
# Processing: Riu Palace Las Americas Komplette Resort-Rundreise & Bewertung | Cancun Mexiko All-Inclusive Nur ...
#     URL: https://www.youtube.com/watch?v=aQMPYfbRCU8
#    ✔ Saved 0 comments.
# Processing: Bewertung eines (für mich) NEUEN Produkts (1175)
#     URL: https://www.youtube.com/watch?v=leiX85z9O80
#    ✔ Saved 71 comments.
# Processing: The Best Reactions To Disturbed "Sound of Silence" Live on CONAN
#     URL: https://www.youtube.com/watch?v=W_NZnNAMZzg
#    ✔ Saved 1000 comments.
# Processing: Meine OMI bewertet YouTube Songs 3.0 😂
#     URL: https://www.youtube.com/watch?v=SEP06jj3d1k
#    ✔ Saved 1000 comments.
# Skipping: already processed https://www.youtube.com/watch?v=-HdUIPGXoxk
# Processing: BEWERTUNG 16tel GRUPPE D | JMC
#     URL: https://www.youtube.com/watch?v=AEu6lrXMxEg
#    ✔ Saved 1000 comments.
# Processing: Top 5 phonk songs of the month
#     URL: https://www.youtube.com/watch?v=rP4uTRihl0o
#    ✔ Saved 1000 comments.
# Processing: Musik Bewertung #shorts
#     URL: https://www.youtube.com/watch?v=ap9qd_NUuss
#    ✔ Saved 0 comments.
# Processing: BEWERTUNG | FINALE | JMC
#     URL: https://www.youtube.com/watch?v=VfKHm4JHflc
#    ✔ Saved 1000 comments.
# Processing: "LIEBES SONG" - CLASHGAMES feat. MEINE FREUNDIN (Official Music Video)
#     URL: https://www.youtube.com/watch?v=0WYFGZTKEN8
#    ✔ Saved 1000 comments.
# Processing: BEWERTUNG 4tel-Finale GRUPPE  A | JMC
#     URL: https://www.youtube.com/watch?v=1HSku5ykRTk
#    ✔ Saved 1000 comments.
# Processing: Voice Coach/Opera Singer REACTION & ANALYSIS Disturbed "The Sound of Silence"
#     URL: https://www.youtube.com/watch?v=uFmNaXAg0sw
#    ✔ Saved 1000 comments.
# Processing: Lil Joey & notsocool (Joey's Jungle & rewinside) / Musikproduzent bewertet "MUSIK" von Youtubern
#     URL: https://www.youtube.com/watch?v=Dn7pVUxpUJQ
