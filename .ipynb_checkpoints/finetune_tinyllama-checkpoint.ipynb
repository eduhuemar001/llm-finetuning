# %%
import os
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from itertools import islice
from torch.utils.data import Dataset

# %%
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
streamed_dataset = load_dataset(
    "wikipedia",
    "20220301.de",
    split="train",
    streaming=True,
    trust_remote_code=True
)

small_dataset = list(islice(streamed_dataset, 5000))

# %%
block_size = 512
tokens = []

for item in small_dataset:
    ids = tokenizer(item["text"], return_attention_mask=False, add_special_tokens=False).input_ids
    tokens.extend(ids + [tokenizer.eos_token_id])  # optional: add EOS after each article

# %%
# Ensure the tokens array has a length of multiple of block size
total_length = len(tokens) - (len(tokens) % block_size)
tokens = tokens[:total_length]

# Split into 512-token chunks
chunks = [tokens[i:i + block_size] for i in range(0, total_length, block_size)]

# %%
from torch.utils.data import Dataset
import torch

class ChunkDataset(Dataset):
    def __init__(self, chunks):
        self.chunks = chunks

    def __len__(self):
        return len(self.chunks)

    def __getitem__(self, idx):
        ids = torch.tensor(self.chunks[idx], dtype=torch.long)
        return {
            "input_ids": ids,
            "labels": ids
        }

train_dataset = ChunkDataset(chunks)
